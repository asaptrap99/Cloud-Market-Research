# %%
import numpy as np

# %%
np.random.randn(100, 2)
# Out:
# array([[ 6.87999739e-01, -1.43632422e+00],
#        [-1.06712885e+00,  3.22314118e+00],
#        [-1.05995823e+00, -3.46955996e-01],
#        [-2.20566917e+00, -1.12650812e+00],
#        [-2.60773665e+00, -9.59590790e-02],
#        [ 3.46422199e-01,  6.49759606e-02],
#        [ 1.46035821e-01,  1.21266906e+00],
#        [-5.37423127e-01,  7.89451580e-01],
#        [ 7.30691924e-01, -1.87441895e+00],
#        [-3.95046430e-01, -3.42692602e-01],
#        [-3.52017364e-01, -4.70812625e-01],
#        [-5.90085080e-01, -4.25267344e-01],
#        [ 9.21657181e-01, -8.04712589e-01],
#        [ 7.51155630e-01,  1.36423349e-01],
#        [-6.58679167e-01, -1.28942348e+00],
#        [-1.74852350e+00, -3.28797774e-01],
#        [-8.20576964e-01,  4.67166205e-02],
#        [-1.73782571e-01, -2.92810170e-01],
#        [-2.82365448e+00, -2.34530900e-01],
#        [-2.98013100e-01,  1.97407328e-01],
#        [ 8.87608675e-02,  1.32920308e+00],
#        [-4.09079469e-01, -7.19639977e-01],
# ...
